# %%
data = [(1,2,3)]
schema = 'id integer,id2 integer,id3 integer'

df = spark.createDataFrame(data,schema)
df.display()

# %%
data1 = [(4,5,6)]
schema1 = 'id integer,id2 integer,id3 integer'

df1 = spark.createDataFrame(data1,schema1)
df1.display()

# %%
df_all = df.union(df1)

# %%
df_all.display()
